# %%
#採用PCA降維，找出特徵變數，收斂速度較快
#變數變換: log, one-hot-encoding，可增加準確度
#資料預處理: 移除空值，而不是塞平均數，準確度更好 (要看資料而定)
#離群值處理: 使用Huber方法

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.metrics import make_scorer
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.metrics import r2_score
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
#另外一種高階API，類似keras
import tflearn
import tensorflow as tf
import seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
#資料集是一個房價的資訊


import os

os.listdir("./")
# Out:
# ['.ipynb_checkpoints', 'svm_svr_2.ipynb', 'test.csv', 'train.csv']

# %%
train=pd.read_csv('train.csv')
labels=train["SalePrice"]
test=pd.read_csv('test.csv')

#合併兩個欄位一樣的df
#用concat
df=pd.concat([train,test],ignore_index=True)
df=df.drop(["SalePrice"],axis=1)

ids=test["Id"]

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
df.shape
# Out:
# (2919, 80)

# %%
#查看多少個null
nans=pd.isnull(df).sum()
nans[nans>0]
# Out:
# Alley           2721
# BsmtCond          82
# BsmtExposure      82
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtFinType1      79
# BsmtFinType2      80
# BsmtFullBath       2
# BsmtHalfBath       2
# BsmtQual          81
# BsmtUnfSF          1
# Electrical         1
# Exterior1st        1
# Exterior2nd        1
# Fence           2348
# FireplaceQu     1420
# Functional         2
# GarageArea         1
# GarageCars         1
# GarageCond       159
# GarageFinish     159
# GarageQual       159
# GarageType       157
# GarageYrBlt      159
# KitchenQual        1
# LotFrontage      486
# MSZoning           4
# MasVnrArea        23
# MasVnrType        24
# MiscFeature     2814
# PoolQC          2909
# SaleType           1
# TotalBsmtSF        1
# Utilities          2
# dtype: int64

# %%
#大於1000的刪除

df=df.drop("Id", 1)
df=df.drop("Alley", 1)
df=df.drop("Fence", 1)
df=df.drop("MiscFeature", 1)
df=df.drop("PoolQC", 1)
df=df.drop("FireplaceQu", 1)

# %%
#查看欄位型態
df.dtypes.value_counts()
# Out:
# object     38
# int64      25
# float64    11
# dtype: int64

# %%
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1  ... SaleType  ScreenPorch  Street  \
# 0       706.0         0.0          GLQ  ...       WD            0    Pave
# 1       978.0         0.0          ALQ  ...       WD            0    Pave
# 2       486.0         0.0          GLQ  ...       WD            0    Pave
# 3       216.0         0.0          ALQ  ...       WD            0    Pave
# 4       655.0         0.0          GLQ  ...       WD            0    Pave
#
#   TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0            8        856.0    AllPub          0      2003         2003
# 1            6       1262.0    AllPub        298      1976         1976
# 2            6        920.0    AllPub          0      2001         2002
# 3            7        756.0    AllPub          0      1915         1970
# 4            9       1145.0    AllPub        192      2000         2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
#
# [5 rows x 74 columns]

# %%
#將進行one-hot-encoding轉換類別資料
#遺缺值填入中位數
#log變數變換
#無限大(-inf)轉成0

all_columns = df.columns.values
non_categorical=df.describe().columns.values

categorical=[value for value in all_columns if value not in non_categorical]

# %%
#檢視
df[categorical]
# Out:
#      BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0        1Fam       TA           No          GLQ          Unf       Gd
# 1        1Fam       TA           Gd          ALQ          Unf       Gd
# 2        1Fam       TA           Mn          GLQ          Unf       Gd
# 3        1Fam       Gd           No          ALQ          Unf       TA
# 4        1Fam       TA           Av          GLQ          Unf       Gd
# 5        1Fam       TA           No          GLQ          Unf       Gd
# 6        1Fam       TA           Av          GLQ          Unf       Ex
# 7        1Fam       TA           Mn          ALQ          BLQ       Gd
# 8        1Fam       TA           No          Unf          Unf       TA
# 9      2fmCon       TA           No          GLQ          Unf       TA
# 10       1Fam       TA           No          Rec          Unf       TA
# 11       1Fam       TA           No          GLQ          Unf       Ex
# 12       1Fam       TA           No          ALQ          Unf       TA
# 13       1Fam       TA           Av          Unf          Unf       Gd
# 14       1Fam       TA           No          BLQ          Unf       TA
# 15       1Fam       TA           No          Unf          Unf       TA
# 16       1Fam       TA           No          ALQ          Unf       TA
# 17     Duplex      NaN          NaN          NaN          NaN      NaN
# 18       1Fam       TA           No          GLQ          Unf       TA
# 19       1Fam       TA           No          LwQ          Unf       TA
# 20       1Fam       TA           Av          Unf          Unf       Ex
# 21       1Fam       TA           No          Unf          Unf       TA
# 22       1Fam       TA           No          Unf          Unf       Gd
# 23     TwnhsE       TA           No          GLQ          Unf       Gd
# 24       1Fam       TA           Mn          Rec          ALQ       TA
# 25       1Fam       TA           No          Unf          Unf       Gd
# 26       1Fam       TA           Mn          BLQ          Rec       TA
# 27       1Fam       TA           No          GLQ          Unf       Ex
# 28       1Fam       TA           Gd          BLQ          Unf       TA
# 29       1Fam       TA           No          Unf          Unf       TA
# ...       ...      ...          ...          ...          ...      ...
# 2889     1Fam       TA           No          Unf          Unf       TA
# 2890     1Fam       TA           No          Unf          Unf       TA
# 2891     1Fam      NaN          NaN          NaN          NaN      NaN
# 2892   2fmCon       TA           Mn          Unf          Unf       TA
# 2893     1Fam       Fa           No          Unf          Unf       Fa
# 2894   TwnhsE       TA           Gd          GLQ          Unf       Ex
# 2895   TwnhsE       TA           Gd          GLQ          Unf       Ex
# 2896     1Fam       TA           Gd          GLQ          Unf       Gd
# 2897   Duplex       TA           Mn          Unf          Unf       TA
# 2898     1Fam       TA           No          Unf          Unf       Ex
# 2899     1Fam       TA           Av          GLQ          Unf       TA
# 2900     1Fam       TA           Gd          BLQ          Unf       Gd
# 2901     1Fam       TA           Av          GLQ          BLQ       Gd
# 2902     1Fam       Gd           Av          GLQ          Unf       Ex
# 2903     1Fam       TA           Gd          GLQ          Unf       Gd
# 2904     1Fam      NaN          NaN          NaN          NaN      NaN
# 2905   Duplex       TA           Gd          GLQ          Unf       Gd
# 2906   TwnhsE       TA           Mn          Unf          Unf       Gd
# 2907     1Fam       TA           No          ALQ          Unf       TA
# 2908   Duplex       TA           No          BLQ          Unf       TA
# 2909    Twnhs       TA           Av          GLQ          Unf       Gd
# 2910   TwnhsE       TA           No          Rec          Unf       TA
# 2911     1Fam       TA           Av          Rec          BLQ       TA
# 2912    Twnhs       TA           No          Rec          Unf       TA
# 2913    Twnhs       TA           No          Unf          Unf       TA
# 2914    Twnhs       TA           No          Unf          Unf       TA
# 2915   TwnhsE       TA           No          Rec          Unf       TA
# 2916     1Fam       TA           No          ALQ          Unf       TA
# 2917     1Fam       TA           Av          GLQ          Unf       Gd
# 2918     1Fam       TA           Av          LwQ          Unf       Gd
#
#      CentralAir Condition1 Condition2 Electrical  ... MSZoning MasVnrType  \
# 0             Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 1             Y      Feedr       Norm      SBrkr  ...       RL       None
# 2             Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 3             Y       Norm       Norm      SBrkr  ...       RL       None
# 4             Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 5             Y       Norm       Norm      SBrkr  ...       RL       None
# 6             Y       Norm       Norm      SBrkr  ...       RL      Stone
# 7             Y       PosN       Norm      SBrkr  ...       RL      Stone
# 8             Y     Artery       Norm      FuseF  ...       RM       None
# 9             Y     Artery     Artery      SBrkr  ...       RL       None
# 10            Y       Norm       Norm      SBrkr  ...       RL       None
# 11            Y       Norm       Norm      SBrkr  ...       RL      Stone
# 12            Y       Norm       Norm      SBrkr  ...       RL       None
# 13            Y       Norm       Norm      SBrkr  ...       RL      Stone
# 14            Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 15            Y       Norm       Norm      FuseA  ...       RM       None
# 16            Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 17            Y       Norm       Norm      SBrkr  ...       RL       None
# 18            Y       RRAe       Norm      SBrkr  ...       RL       None
# 19            Y       Norm       Norm      SBrkr  ...       RL       None
# 20            Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 21            Y       Norm       Norm      FuseF  ...       RM       None
# 22            Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 23            Y       Norm       Norm      SBrkr  ...       RM       None
# 24            Y       Norm       Norm      SBrkr  ...       RL       None
# 25            Y       Norm       Norm      SBrkr  ...       RL      Stone
# 26            Y       Norm       Norm      SBrkr  ...       RL       None
# 27            Y       Norm       Norm      SBrkr  ...       RL      Stone
# 28            Y       Norm       Norm      SBrkr  ...       RL       None
# 29            N      Feedr       RRNn      SBrkr  ...       RM       None
# ...         ...        ...        ...        ...  ...      ...        ...
# 2889          Y       Norm       Norm      SBrkr  ...       RM       None
# 2890          Y       Norm       Norm      SBrkr  ...       RM    BrkFace
# 2891          N      Feedr       Norm      SBrkr  ...  C (all)       None
# 2892          N       Norm       Norm      SBrkr  ...  C (all)       None
# 2893          N       Norm       Norm      SBrkr  ...  C (all)       None
# 2894          Y       Norm       Norm      SBrkr  ...       RM      Stone
# 2895          Y       Norm       Norm      SBrkr  ...       RM      Stone
# 2896          Y       Norm       Norm      SBrkr  ...       RL       None
# 2897          Y       Norm       Norm      SBrkr  ...       RL       None
# 2898          Y       Norm       Norm      SBrkr  ...       RL       None
# 2899          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 2900          Y       Norm       Norm      SBrkr  ...       RL       None
# 2901          Y       Norm       Norm      SBrkr  ...       RL       None
# 2902          Y       Norm       Norm      SBrkr  ...       RL      Stone
# 2903          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 2904          Y     Artery       Norm      FuseA  ...      NaN       None
# 2905          Y       Norm       Norm      SBrkr  ...       RM    BrkFace
# 2906          Y       Norm       Norm      SBrkr  ...       RM       None
# 2907          Y       Norm       Norm      SBrkr  ...       RL       None
# 2908          Y       Norm       Norm      SBrkr  ...       RL       None
# 2909          Y       Norm       Norm      SBrkr  ...       RM       None
# 2910          Y       Norm       Norm      SBrkr  ...       RM       None
# 2911          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 2912          Y       Norm       Norm      SBrkr  ...       RM       None
# 2913          Y       Norm       Norm      SBrkr  ...       RM       None
# 2914          Y       Norm       Norm      SBrkr  ...       RM       None
# 2915          Y       Norm       Norm      SBrkr  ...       RM       None
# 2916          Y       Norm       Norm      SBrkr  ...       RL       None
# 2917          Y       Norm       Norm      SBrkr  ...       RL       None
# 2918          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
#
#      Neighborhood PavedDrive RoofMatl RoofStyle SaleCondition SaleType Street  \
# 0         CollgCr          Y  CompShg     Gable        Normal       WD   Pave
# 1         Veenker          Y  CompShg     Gable        Normal       WD   Pave
# 2         CollgCr          Y  CompShg     Gable        Normal       WD   Pave
# 3         Crawfor          Y  CompShg     Gable       Abnorml       WD   Pave
# 4         NoRidge          Y  CompShg     Gable        Normal       WD   Pave
# 5         Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 6         Somerst          Y  CompShg     Gable        Normal       WD   Pave
# 7          NWAmes          Y  CompShg     Gable        Normal       WD   Pave
# 8         OldTown          Y  CompShg     Gable       Abnorml       WD   Pave
# 9         BrkSide          Y  CompShg     Gable        Normal       WD   Pave
# 10         Sawyer          Y  CompShg       Hip        Normal       WD   Pave
# 11        NridgHt          Y  CompShg       Hip       Partial      New   Pave
# 12         Sawyer          Y  CompShg       Hip        Normal       WD   Pave
# 13        CollgCr          Y  CompShg     Gable       Partial      New   Pave
# 14          NAmes          Y  CompShg       Hip        Normal       WD   Pave
# 15        BrkSide          Y  CompShg     Gable        Normal       WD   Pave
# 16          NAmes          Y  CompShg     Gable        Normal       WD   Pave
# 17         Sawyer          Y  CompShg     Gable        Normal       WD   Pave
# 18        SawyerW          Y  CompShg     Gable        Normal       WD   Pave
# 19          NAmes          Y  CompShg       Hip       Abnorml      COD   Pave
# 20        NridgHt          Y  CompShg     Gable       Partial      New   Pave
# 21         IDOTRR          N  CompShg     Gable        Normal       WD   Pave
# 22        CollgCr          Y  CompShg       Hip        Normal       WD   Pave
# 23        MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 24         Sawyer          Y  CompShg     Gable        Normal       WD   Pave
# 25        NridgHt          Y  CompShg     Gable        Normal       WD   Pave
# 26          NAmes          Y  CompShg     Gable        Normal       WD   Pave
# 27        NridgHt          Y  CompShg     Gable        Normal       WD   Pave
# 28          NAmes          Y  CompShg     Gable        Normal       WD   Pave
# 29        BrkSide          Y  CompShg     Gable        Normal       WD   Pave
# ...           ...        ...      ...       ...           ...      ...    ...
# 2889       IDOTRR          N  CompShg     Gable        Normal       WD   Pave
# 2890       IDOTRR          Y  CompShg     Gable        Normal       WD   Pave
# 2891       IDOTRR          N  CompShg     Gable       Abnorml       WD   Pave
# 2892       IDOTRR          Y  CompShg     Gable       Abnorml       WD   Pave
# 2893       IDOTRR          N  CompShg     Gable        Normal       WD   Grvl
# 2894      Crawfor          Y  CompShg       Hip       Partial      New   Pave
# 2895      Crawfor          Y  CompShg       Hip        Normal       WD   Pave
# 2896      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2897      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2898      Mitchel          Y  CompShg       Hip        Normal       WD   Pave
# 2899      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2900       Timber          Y  Tar&Grv     Gable        Alloca       WD   Pave
# 2901       Timber          Y  CompShg     Gable        Normal       WD   Pave
# 2902       Timber          Y  CompShg     Gable       Partial      New   Pave
# 2903       Timber          Y  CompShg       Hip       Partial      New   Pave
# 2904      Mitchel          N  CompShg     Gable        Normal       WD   Pave
# 2905      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2906      MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 2907      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2908      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2909      MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 2910      MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 2911      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2912      MeadowV          Y  CompShg     Gable       Abnorml       WD   Pave
# 2913      MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 2914      MeadowV          Y  CompShg     Gable        Normal       WD   Pave
# 2915      MeadowV          Y  CompShg     Gable       Abnorml       WD   Pave
# 2916      Mitchel          Y  CompShg     Gable       Abnorml       WD   Pave
# 2917      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
# 2918      Mitchel          Y  CompShg     Gable        Normal       WD   Pave
#
#      Utilities
# 0       AllPub
# 1       AllPub
# 2       AllPub
# 3       AllPub
# 4       AllPub
# 5       AllPub
# 6       AllPub
# 7       AllPub
# 8       AllPub
# 9       AllPub
# 10      AllPub
# 11      AllPub
# 12      AllPub
# 13      AllPub
# 14      AllPub
# 15      AllPub
# 16      AllPub
# 17      AllPub
# 18      AllPub
# 19      AllPub
# 20      AllPub
# 21      AllPub
# 22      AllPub
# 23      AllPub
# 24      AllPub
# 25      AllPub
# 26      AllPub
# 27      AllPub
# 28      AllPub
# 29      AllPub
# ...        ...
# 2889    AllPub
# 2890    AllPub
# 2891    AllPub
# 2892    AllPub
# 2893    AllPub
# 2894    AllPub
# 2895    AllPub
# 2896    AllPub
# 2897    AllPub
# 2898    AllPub
# 2899    AllPub
# 2900    AllPub
# 2901    AllPub
# 2902    AllPub
# 2903    AllPub
# 2904    AllPub
# 2905    AllPub
# 2906    AllPub
# 2907    AllPub
# 2908    AllPub
# 2909    AllPub
# 2910    AllPub
# 2911    AllPub
# 2912    AllPub
# 2913    AllPub
# 2914    AllPub
# 2915    AllPub
# 2916    AllPub
# 2917    AllPub
# 2918    AllPub
#
# [2919 rows x 38 columns]
