# %%
#採用PCA降維，找出特徵變數，收斂速度較快
#變數變換: log, one-hot-encoding，可增加準確度
#資料預處理: 移除空值，而不是塞平均數，準確度更好 (要看資料而定)
#離群值處理: 使用Huber方法

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import Imputer
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.metrics import make_scorer
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.metrics import r2_score
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
#另外一種高階API，類似keras
import tflearn
import tensorflow as tf
import seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
#資料集是一個房價的資訊


import os

os.listdir("./")
# Out:
# ['.ipynb_checkpoints', 'svm_svr_2.ipynb', 'test.csv', 'train.csv']

# %%
train=pd.read_csv('train.csv')
labels=train["SalePrice"]
test=pd.read_csv('test.csv')

#合併兩個欄位一樣的df
#用concat
df=pd.concat([train,test],ignore_index=True)
df=df.drop(["SalePrice"],axis=1)

ids=test["Id"]

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train.shape
# Out:
# (1460, 81)

# %%
df.shape
# Out:
# (2919, 80)

# %%
#查看多少個null
nans=pd.isnull(df).sum()
nans[nans>0]
# Out:
# array([], dtype=int32)

# %%
#大於1000的刪除

df=df.drop("Id", 1)
df=df.drop("Alley", 1)
df=df.drop("Fence", 1)
df=df.drop("MiscFeature", 1)
df=df.drop("PoolQC", 1)
df=df.drop("FireplaceQu", 1)

# %%
#查看欄位型態
df.dtypes.value_counts()
# Out:
# object     38
# int64      25
# float64    11
# dtype: int64

# %%
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType BsmtCond BsmtExposure  \
# 0       856       854          0             3     1Fam       TA           No
# 1      1262         0          0             3     1Fam       TA           Gd
# 2       920       866          0             3     1Fam       TA           Mn
# 3       961       756          0             3     1Fam       Gd           No
# 4      1145      1053          0             4     1Fam       TA           Av
#
#    BsmtFinSF1  BsmtFinSF2 BsmtFinType1  ... SaleType  ScreenPorch  Street  \
# 0       706.0         0.0          GLQ  ...       WD            0    Pave
# 1       978.0         0.0          ALQ  ...       WD            0    Pave
# 2       486.0         0.0          GLQ  ...       WD            0    Pave
# 3       216.0         0.0          ALQ  ...       WD            0    Pave
# 4       655.0         0.0          GLQ  ...       WD            0    Pave
#
#   TotRmsAbvGrd  TotalBsmtSF Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0            8        856.0    AllPub          0      2003         2003
# 1            6       1262.0    AllPub        298      1976         1976
# 2            6        920.0    AllPub          0      2001         2002
# 3            7        756.0    AllPub          0      1915         1970
# 4            9       1145.0    AllPub        192      2000         2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
#
# [5 rows x 74 columns]

# %%
#將進行one-hot-encoding轉換類別資料
#遺缺值填入中位數
#log變數變換
#無限大(-inf)轉成0

all_columns = df.columns.values
non_categorical=df.describe().columns.values

categorical=[value for value in all_columns if value not in non_categorical]

# %%
#檢視
df[categorical].head()
# Out:
#   BldgType BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2 BsmtQual  \
# 0     1Fam       TA           No          GLQ          Unf       Gd
# 1     1Fam       TA           Gd          ALQ          Unf       Gd
# 2     1Fam       TA           Mn          GLQ          Unf       Gd
# 3     1Fam       Gd           No          ALQ          Unf       TA
# 4     1Fam       TA           Av          GLQ          Unf       Gd
#
#   CentralAir Condition1 Condition2 Electrical  ... MSZoning MasVnrType  \
# 0          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 1          Y      Feedr       Norm      SBrkr  ...       RL       None
# 2          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
# 3          Y       Norm       Norm      SBrkr  ...       RL       None
# 4          Y       Norm       Norm      SBrkr  ...       RL    BrkFace
#
#   Neighborhood PavedDrive RoofMatl RoofStyle SaleCondition SaleType Street  \
# 0      CollgCr          Y  CompShg     Gable        Normal       WD   Pave
# 1      Veenker          Y  CompShg     Gable        Normal       WD   Pave
# 2      CollgCr          Y  CompShg     Gable        Normal       WD   Pave
# 3      Crawfor          Y  CompShg     Gable       Abnorml       WD   Pave
# 4      NoRidge          Y  CompShg     Gable        Normal       WD   Pave
#
#   Utilities
# 0    AllPub
# 1    AllPub
# 2    AllPub
# 3    AllPub
# 4    AllPub
#
# [5 rows x 38 columns]

# %%
#one-hot-encoding

df=pd.get_dummies(df)

# %%
#塞值

imp=Imputer(missing_values='NaN', strategy='most_frequent', axis=0)
df=imp.fit_transform(df)

#變數變換
df=np.log(df)
labels=np.log(labels)

df[df==-np.inf]=0

# %%
#切割

train=df[:1460]
test=df[1460:]

print(train.shape)
print(labels.shape)
print(test.shape)
# Out:
# (1460, 270)
# (1460,)
# (1459, 270)

# %%
clf=svm.SVR()
clf.fit(train,labels)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
test_labels=clf.predict(test)

# %%
test_labels.shape
# Out:
# (1459,)

# %%
price_lable=np.exp(test_labels)

# %%
price_lable
# Out:
# array([135434.9400385 , 205808.52634403, 187911.45262461, ...,
#        176464.29286235, 109135.94024166, 254421.42909117])

# %%
print(price_lable)
# Out:
# [135434.9400385  205808.52634403 187911.45262461 ... 176464.29286235
#  109135.94024166 254421.42909117]

# %%
sub=pd.DataFrame({
    "SalePrice":price_lable
})

# %%
sub.head()
# Out:
#        SalePrice
# 0  135434.940039
# 1  205808.526344
# 2  187911.452625
# 3  202696.372009
# 4  179084.218149

# %%
test_data = pd.read_csv('test.csv')

# %%
result =  test_data.append(sub)

# %%
result['SalePrice'] = sub['SalePrice']

# %%
result['SalePrice'].head()
# Out:
# 0    135434.940039
# 1    205808.526344
# 2    187911.452625
# 3    202696.372009
# 4    179084.218149
# Name: SalePrice, dtype: float64

# %%
result.to_csv("sample_submission.csv", index=False)

# %%
#feature reduction
#縮減變數
#找出適合的n_component
#whiten: 讓每個變數都有相同的方差

pca=PCA(whiten=True)
pca.fit(df)
variance=pd.DataFrame(pca)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0        896.0       0.0        0.0   NaN           2.0     1Fam       TA
# 1       1329.0       0.0        0.0   NaN           3.0     1Fam       TA
# 2        928.0     701.0        0.0   NaN           3.0     1Fam       TA
# 3        926.0     678.0        0.0   NaN           3.0     1Fam       TA
# 4       1280.0       0.0        0.0   NaN           2.0   TwnhsE       TA
# 5        763.0     892.0        0.0   NaN           3.0     1Fam       TA
# 6       1187.0       0.0        0.0   NaN           3.0     1Fam       TA
# 7        789.0     676.0        0.0   NaN           3.0     1Fam       TA
# 8       1341.0       0.0        0.0   NaN           2.0     1Fam       TA
# 9        882.0       0.0        0.0   NaN           2.0     1Fam       TA
# 10      1337.0       0.0        0.0   NaN           2.0   TwnhsE       TA
# 11       483.0     504.0        0.0   NaN           2.0    Twnhs       TA
# 12       525.0     567.0        0.0   NaN           3.0    Twnhs       TA
# 13       855.0     601.0        0.0   NaN           3.0    Twnhs       TA
# 14       836.0       0.0        0.0   NaN           2.0    Twnhs       TA
# 15      1627.0     707.0        0.0   NaN           3.0     1Fam       TA
# 16      1544.0       0.0        0.0   NaN           3.0     1Fam       TA
# 17      1698.0       0.0        0.0   NaN           3.0     1Fam       TA
# 18      1822.0       0.0        0.0   NaN           3.0     1Fam       TA
# 19      2696.0       0.0        0.0   NaN           3.0     1Fam       TA
# 20      1687.0     563.0        0.0   NaN           3.0     1Fam       TA
# 21      1370.0       0.0        0.0   NaN           2.0   TwnhsE       TA
# 22      1324.0       0.0        0.0   NaN           3.0     1Fam       TA
# 23      1145.0       0.0        0.0   NaN           2.0   TwnhsE       TA
# 24       744.0     630.0        0.0   NaN           3.0     1Fam       TA
# 25       847.0     886.0        0.0   NaN           3.0     1Fam       TA
# 26      1645.0     830.0        0.0   NaN           4.0     1Fam       TA
# 27      1595.0       0.0        0.0   NaN           2.0     1Fam       TA
# 28      1218.0       0.0        0.0   NaN           2.0     1Fam       TA
# 29      1468.0       0.0        0.0   NaN           2.0     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 1429       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1430       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1431       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1432       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1433       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1434       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1435       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1436       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1437       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1438       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1439       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1440       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1441       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1442       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1443       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1444       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1445       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1446       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1447       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1448       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1449       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1450       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1451       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1452       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1453       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1454       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1455       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1456       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1457       NaN       NaN        NaN   NaN           NaN      NaN      NaN
# 1458       NaN       NaN        NaN   NaN           NaN      NaN      NaN
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... SaleType ScreenPorch  Street  \
# 0              No       468.0       144.0  ...       WD       120.0    Pave
# 1              No       923.0         0.0  ...       WD         0.0    Pave
# 2              No       791.0         0.0  ...       WD         0.0    Pave
# 3              No       602.0         0.0  ...       WD         0.0    Pave
# 4              No       263.0         0.0  ...       WD       144.0    Pave
# 5              No         0.0         0.0  ...       WD         0.0    Pave
# 6              No       935.0         0.0  ...       WD         0.0    Pave
# 7              No         0.0         0.0  ...       WD         0.0    Pave
# 8              Gd       637.0         0.0  ...       WD         0.0    Pave
# 9              No       804.0        78.0  ...       WD         0.0    Pave
# 10             No      1051.0         0.0  ...       WD         0.0    Pave
# 11             No       156.0         0.0  ...      COD         0.0    Pave
# 12             No       300.0         0.0  ...       WD         0.0    Pave
# 13             No       514.0         0.0  ...       WD         0.0    Pave
# 14             No         0.0         0.0  ...       WD         0.0    Pave
# 15             No         0.0         0.0  ...      New         0.0    Pave
# 16             No         0.0         0.0  ...      New         0.0    Pave
# 17             No       110.0         0.0  ...       WD         0.0    Pave
# 18             No        28.0         0.0  ...       WD         0.0    Pave
# 19             Gd      1373.0         0.0  ...       WD         0.0    Pave
# 20             Gd       578.0         0.0  ...       WD         0.0    Pave
# 21             Mn        24.0         0.0  ...       WD         0.0    Pave
# 22             No         0.0         0.0  ...       WD         0.0    Pave
# 23             Av        16.0         0.0  ...       WD         0.0    Pave
# 24             No       326.0         0.0  ...       WD         0.0    Pave
# 25             No         0.0         0.0  ...       WD         0.0    Pave
# 26             No         0.0         0.0  ...       WD       256.0    Pave
# 27            NaN         0.0         0.0  ...       WD         0.0    Pave
# 28             No         0.0         0.0  ...      New         0.0    Pave
# 29             No      1414.0         0.0  ...       WD       216.0    Pave
# ...           ...         ...         ...  ...      ...         ...     ...
# 1429          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1430          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1431          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1432          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1433          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1434          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1435          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1436          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1437          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1438          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1439          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1440          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1441          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1442          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1443          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1444          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1445          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1446          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1447          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1448          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1449          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1450          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1451          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1452          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1453          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1454          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1455          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1456          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1457          NaN         NaN         NaN  ...      NaN         NaN     NaN
# 1458          NaN         NaN         NaN  ...      NaN         NaN     NaN
#
#       TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0              5.0       882.0     AllPub      140.0    1961.0       1961.0
# 1              6.0      1329.0     AllPub      393.0    1958.0       1958.0
# 2              6.0       928.0     AllPub      212.0    1997.0       1998.0
# 3              7.0       926.0     AllPub      360.0    1998.0       1998.0
# 4              5.0      1280.0     AllPub        0.0    1992.0       1992.0
# 5              7.0       763.0     AllPub      157.0    1993.0       1994.0
# 6              6.0      1168.0     AllPub      483.0    1992.0       2007.0
# 7              7.0       789.0     AllPub        0.0    1998.0       1998.0
# 8              5.0      1300.0     AllPub      192.0    1990.0       1990.0
# 9              4.0       882.0     AllPub      240.0    1970.0       1970.0
# 10             5.0      1405.0     AllPub      203.0    1999.0       1999.0
# 11             5.0       483.0     AllPub      275.0    1971.0       1971.0
# 12             6.0       525.0     AllPub        0.0    1971.0       1971.0
# 13             6.0       855.0     AllPub      173.0    1975.0       1975.0
# 14             4.0       836.0     AllPub        0.0    1975.0       1975.0
# 15            10.0      1590.0     AllPub      144.0    2009.0       2010.0
# 16             7.0      1544.0     AllPub        0.0    2009.0       2010.0
# 17             7.0      1698.0     AllPub      192.0    2005.0       2005.0
# 18             8.0      1822.0     AllPub        0.0    2005.0       2006.0
# 19            10.0      2846.0     AllPub      220.0    2003.0       2004.0
# 20             7.0      1671.0     AllPub      238.0    2002.0       2002.0
# 21             6.0      1370.0     AllPub      120.0    2006.0       2006.0
# 22             6.0      1324.0     AllPub       36.0    2005.0       2005.0
# 23             6.0      1145.0     AllPub      100.0    2006.0       2006.0
# 24             7.0       384.0     AllPub      100.0    2004.0       2004.0
# 25             7.0       847.0     AllPub      144.0    2004.0       2004.0
# 26             7.0      1629.0     AllPub       23.0    1998.0       1998.0
# 27             6.0      1595.0     AllPub      144.0    2005.0       2006.0
# 28             4.0      1218.0     AllPub        0.0    2009.0       2010.0
# 29             6.0      1468.0     AllPub        0.0    2005.0       2005.0
# ...            ...         ...        ...        ...       ...          ...
# 1429           NaN         NaN        NaN        NaN       NaN          NaN
# 1430           NaN         NaN        NaN        NaN       NaN          NaN
# 1431           NaN         NaN        NaN        NaN       NaN          NaN
# 1432           NaN         NaN        NaN        NaN       NaN          NaN
# 1433           NaN         NaN        NaN        NaN       NaN          NaN
# 1434           NaN         NaN        NaN        NaN       NaN          NaN
# 1435           NaN         NaN        NaN        NaN       NaN          NaN
# 1436           NaN         NaN        NaN        NaN       NaN          NaN
# 1437           NaN         NaN        NaN        NaN       NaN          NaN
# 1438           NaN         NaN        NaN        NaN       NaN          NaN
# 1439           NaN         NaN        NaN        NaN       NaN          NaN
# 1440           NaN         NaN        NaN        NaN       NaN          NaN
# 1441           NaN         NaN        NaN        NaN       NaN          NaN
# 1442           NaN         NaN        NaN        NaN       NaN          NaN
# 1443           NaN         NaN        NaN        NaN       NaN          NaN
# 1444           NaN         NaN        NaN        NaN       NaN          NaN
# 1445           NaN         NaN        NaN        NaN       NaN          NaN
# 1446           NaN         NaN        NaN        NaN       NaN          NaN
# 1447           NaN         NaN        NaN        NaN       NaN          NaN
# 1448           NaN         NaN        NaN        NaN       NaN          NaN
# 1449           NaN         NaN        NaN        NaN       NaN          NaN
# 1450           NaN         NaN        NaN        NaN       NaN          NaN
# 1451           NaN         NaN        NaN        NaN       NaN          NaN
# 1452           NaN         NaN        NaN        NaN       NaN          NaN
# 1453           NaN         NaN        NaN        NaN       NaN          NaN
# 1454           NaN         NaN        NaN        NaN       NaN          NaN
# 1455           NaN         NaN        NaN        NaN       NaN          NaN
# 1456           NaN         NaN        NaN        NaN       NaN          NaN
# 1457           NaN         NaN        NaN        NaN       NaN          NaN
# 1458           NaN         NaN        NaN        NaN       NaN          NaN
#
#       YrSold
# 0     2010.0
# 1     2010.0
# 2     2010.0
# 3     2010.0
# 4     2010.0
# 5     2010.0
# 6     2010.0
# 7     2010.0
# 8     2010.0
# 9     2010.0
# 10    2010.0
# 11    2010.0
# 12    2010.0
# 13    2010.0
# 14    2010.0
# 15    2010.0
# 16    2010.0
# 17    2010.0
# 18    2010.0
# 19    2010.0
# 20    2010.0
# 21    2010.0
# 22    2010.0
# 23    2010.0
# 24    2010.0
# 25    2010.0
# 26    2010.0
# 27    2010.0
# 28    2010.0
# 29    2010.0
# ...      ...
# 1429     NaN
# 1430     NaN
# 1431     NaN
# 1432     NaN
# 1433     NaN
# 1434     NaN
# 1435     NaN
# 1436     NaN
# 1437     NaN
# 1438     NaN
# 1439     NaN
# 1440     NaN
# 1441     NaN
# 1442     NaN
# 1443     NaN
# 1444     NaN
# 1445     NaN
# 1446     NaN
# 1447     NaN
# 1448     NaN
# 1449     NaN
# 1450     NaN
# 1451     NaN
# 1452     NaN
# 1453     NaN
# 1454     NaN
# 1455     NaN
# 1456     NaN
# 1457     NaN
# 1458     NaN
#
# [2918 rows x 81 columns]
